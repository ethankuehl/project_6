# %% [markdown]
# # Problem Statements
#
# 1. Problem Statement:
# MLB scouting departments have become heavily reliant on data analysis since the advent of Moneyball. Teams are now looking to get that extra edge from Machine Learning, so the goal of this project is to use historical data from Baseball-Reference to predict whether an offensive player is going to be an All-Star this upcoming year.
#
#
# 2. Problem Statement:
# The 2017 Houston Astros achieved infamy for their Major League Baseball cheating scandal by relaying what pitch was about to be thrown to their hitters. The goal of this project is to determine whether a Machine Learning model can accurately predict the next pitch coming based on game situation and current pitcher’s arsenal.

# %%
import pandas as pd

from baseball_scraper import playerid_lookup
from baseball_scraper import statcast_pitcher
from baseball_scraper import batting_stats_range
from baseball_scraper import statcast
from baseball_scraper import statcast_batter

# %%
pd.set_option('display.max_columns', 200)

# %%
data = batting_stats_range('2008-05-01', '2020-10-27')
data.head()
# Out:
#                  Name  Age  #days            Lev                    Tm    G  \
# 1       David Aardsma   33   2060  MLB-NL,MLB-AL        Atlanta,Boston    2
# 2       Fernando Abad   30   1765  MLB-NL,MLB-AL     Houston,Minnesota    7
# 3  Reggie Abercrombie   27   4530         MLB-NL               Houston   32
# 4         Bobby Abreu   40   2339  MLB-AL,MLB-NL  Los Angeles,New York  751
# 5          José Abreu   33    148         MLB-AL               Chicago  961
#
#      PA    AB    R     H   2B  3B   HR  RBI   BB  IBB   SO  HBP  SH  SF  GDP  \
# 1     2     2    0     0    0   0    0    0    0    0    2    0   0   0    0
# 2     9     9    0     1    0   0    0    0    0    0    5    0   0   0    1
# 3    60    55   10    17    5   0    2    5    1    0   23    2   1   1    0
# 4  2901  2493  368   676  155  10   64  363  381   20  520    5   1  21   57
# 5  4168  3787  526  1114  233  14  198  671  263   51  835   83   0  35  120
#
#     SB  CS     BA    OBP    SLG    OPS  mlb_ID
# 1    0   0  0.000  0.000  0.000  0.000  430911
# 2    0   0  0.111  0.111  0.111  0.222  472551
# 3    5   2  0.309  0.339  0.509  0.848  430631
# 4  103  30  0.271  0.366  0.418  0.785  110029
# 5   10   2  0.294  0.350  0.520  0.870  547989

# %%
len(data)
# Out:
# 3249

# %%
data[data['G'] > 100]
# Out:
#                    Name  Age  #days            Lev  \
# 4           Bobby Abreu   40   2339  MLB-AL,MLB-NL
# 5            José Abreu   33    148         MLB-AL
# 6            Tony Abreu   29   2401  MLB-NL,MLB-AL
# 8         Dustin Ackley   28   1730         MLB-AL
# 10     Ronald Acuna Jr.   22    149         MLB-NL
# ...                 ...  ...    ...            ...
# 3374     Ryan Zimmerman   34    512         MLB-NL
# 3375  Jordan Zimmermann   33    614  MLB-NL,MLB-AL
# 3376         Barry Zito   35   2707         MLB-NL
# 3377        Ben Zobrist   38    512  MLB-AL,MLB-NL
# 3378        Mike Zunino   29    149         MLB-AL
#
#                                                  Tm     G    PA    AB    R  \
# 4                              Los Angeles,New York   751  2901  2493  368
# 5                                           Chicago   961  4168  3787  526
# 6     Arizona,San Francisco,Kansas City,Los Angeles   163   438   414   42
# 8                                  Seattle,New York   624  2348  2126  261
# 10                                          Atlanta   313  1404  1219  251
# ...                                             ...   ...   ...   ...  ...
# 3374                                     Washington  1320  5537  4958  736
# 3375                             Washington,Detroit   175   390   334   18
# 3376                                  San Francisco   150   310   247   10
# 3377          Tampa Bay,Chicago,Kansas City,Oakland  1565  6533  5600  866
# 3378                              Seattle,Tampa Bay   687  2460  2226  244
#
#          H   2B  3B   HR  RBI   BB  IBB    SO  HBP  SH  SF  GDP   SB  CS  \
# 4      676  155  10   64  363  381   20   520    5   1  21   57  103  30
# 5     1114  233  14  198  671  263   51   835   83   0  35  120   10   2
# 6      102   25   5    4   43   15    1    96    2   1   6   15    2   3
# 8      512   94  18   46  216  194   10   420    5  11  12   25   31  11
# 10     342   59   6   81  194  159    8   371   19   0   4   15   61  13
# ...    ...  ...  ..  ...  ...  ...  ...   ...  ...  ..  ..  ...  ...  ..
# 3374  1384  295  14  223  795  499   33  1027   25   0  54  160   28   6
# 3375    56    6   0    1   15   10    0   104    0  44   2    2    0   0
# 3376    26    0   0    0    8   16    0    66    0  47   0    4    0   0
# 3377  1510  341  42  164  741  819   34   947   30  22  62  121  112  34
# 3378   446  100   3  108  283  164    1   849   51   8  11   42    2   4
#
#          BA    OBP    SLG    OPS  mlb_ID
# 4     0.271  0.366  0.418  0.785  110029
# 5     0.294  0.350  0.520  0.870  547989
# 6     0.246  0.272  0.360  0.632  473234
# 8     0.241  0.304  0.367  0.671  554429
# 10    0.281  0.371  0.538  0.909  660670
# ...     ...    ...    ...    ...     ...
# 3374  0.279  0.345  0.479  0.824  475582
# 3375  0.168  0.191  0.195  0.385  519455
# 3376  0.105  0.160  0.105  0.265  217096
# 3377  0.270  0.362  0.433  0.796  450314
# 3378  0.200  0.270  0.394  0.663  572287
#
# [1222 rows x 28 columns]

# %%
hitters = data[data['G'] > 100]

hitter_ids = hitters['mlb_ID'].to_list()

# %%
hitter_ids
# Out:
# [110029,
#  547989,
#  473234,
#  554429,
#  660670,
#  542436,
#  642715,
#  572669,
#  571431,
#  451192,
#  501303,
#  542583,
#  605113,
#  593643,
#  645277,
#  570489,
#  595751,
#  450315,
#  656185,
#  501659,
#  546991,
#  624413,
#  475174,
#  571437,
#  514888,
#  476883,
#  506560,
#  407792,
#  435042,
#  605119,
#  502624,
#  110236,
#  461811,
#  641313,
#  435180,
#  462101,
#  609280,
#  150449,
#  493114,
#  606115,
#  542455,
#  571448,
#  450317,
#  435078,
#  650333,
#  453562,
#  276520,
#  605125,
#  641319,
#  425548,
#  110383,
#  110385,
#  592122,
#  488671,
#  449107,
#  430947,
#  430632,
#  664056,
#  595879,
#  456701,
#  425557,
#  434633,
#  132720,
#  434605,
#  542908,
#  150148,
#  408036,
#  425549,
#  605131,
#  488681,
#  446381,
#  571466,
#  620439,
#  430583,
#  435558,
#  641343,
#  430832,
#  488689,
#  424726,
#  607461,
#  493596,
#  542921,
#  605137,
#  150071,
#  641355,
#  474832,
#  136860,
#  134181,
#  643217,
#  204020,
#  465668,
#  407556,
#  450641,
#  542932,
#  435358,
#  400140,
#  542194,
#  605141,
#  488703,
#  624415,
#  451532,
#  595885,
#  444448,
#  453568,
#  232694,
#  408213,
#  433217,
#  453923,
#  111072,
#  452035,
#  430599,
#  518466,
#  217100,
#  150398,
#  453269,
#  593428,
#  460267,
#  460131,
#  466988,
#  593528,
#  474865,
#  623520,
#  571506,
#  430652,
#  488721,
#  456422,
#  435624,
#  598265,
#  150396,
#  488726,
#  542963,
#  137140,
#  460075,
#  608324,
#  458582,
#  621446,
#  518500,
#  502126,
#  542979,
#  457803,
#  429731,
#  592178,
#  407833,
#  459941,
#  518516,
#  150359,
#  542993,
#  150100,
#  502034,
#  430927,
#  460077,
#  456714,
#  621439,
#  407781,
#  291565,
#  452678,
#  465784,
#  466320,
#  408234,
#  111851,
#  502239,
#  456715,
#  430912,
#  111867,
#  594777,
#  641432,
#  430948,
#  622666,
#  111904,
#  542999,
#  493472,
#  600869,
#  592192,
#  429664,
#  408305,
#  605170,
#  455077,
#  572761,
#  485567,
#  448276,
#  425206,
#  452080,
#  474892,
#  592200,
#  488768,
#  458210,
#  592206,
#  112116,
#  456078,
#  605612,
#  488771,
#  112128,
#  135783,
#  516770,
#  112131,
#  595909,
#  430592,
#  518542,
#  465041,
#  493316,
#  468504,
#  656305,
#  543022,
#  346795,
#  136767,
#  656308,
#  455139,
#  502082,
#  596847,
#  425783,
#  425508,
#  465674,
#  112316,
#  459943,
#  502182,
#  458085,
#  499624,
#  543037,
#  607385,
#  112526,
#  518568,
#  502125,
#  624424,
#  474233,
#  462405,
#  468429,
#  575929,
#  643265,
#  133321,
#  571578,
#  641477,
#  449786,
#  621043,
#  429781,
#  400120,
#  112736,
#  502161,
#  592230,
#  518577,
#  446359,
#  501800,
#  543063,
#  408307,
#  641487,
#  150317,
#  424825,
#  543068,
#  425853,
#  460067,
#  458501,
#  443558,
#  488810,
#  150212,
#  456501,
#  518586,
#  488811,
#  400091,
#  596144,
#  488818,
#  518595,
#  621311,
#  113028,
#  458668,
#  571602,
#  605200,
#  448801,
#  477195,
#  605204,
#  501981,
#  434658,
#  457477,
#  474443,
#  407822,
#  621573,
#  594798,
#  430203,
#  657557,
#  113232,
#  113240,
#  547170,
#  133225,
#  544925,
#  456121,
#  136660,
#  518614,
#  543101,
#  592261,
#  435622,
#  646240,
#  455088,
#  649557,
#  553869,
#  429841,
#  650490,
#  543105,
#  447736,
#  572816,
#  285079,
#  518618,
#  594694,
#  543108,
#  641525,
#  425785,
#  518625,
#  453228,
#  518626,
#  425491,
#  453303,
#  572821,
#  641531,
#  136770,
#  452220,
#  592273,
#  446263,
#  622110,
#  621453,
#  435043,
#  452668,
#  408219,
#  455167,
#  276055,
#  594807,
#  113679,
#  502481,
#  594809,
#  275930,
#  669242,
#  113744,
#  454560,
#  407885,
#  453056,
#  518653,
#  429665,
#  641553,
#  113889,
#  640447,
#  444876,
#  500871,
#  488862,
#  457787,
#  444843,
#  452783,
#  276361,
#  571657,
#  605227,
#  543148,
#  150268,
#  425902,
#  435222,
#  408210,
#  605233,
#  475247,
#  664058,
#  435520,
#  570717,
#  527038,
#  465753,
#  452095,
#  592314,
#  430917,
#  523253,
#  451594,
#  444844,
#  664034,
#  450204,
#  464433,
#  596748,
#  425796,
#  435623,
#  545338,
#  624428,
#  640449,
#  453943,
#  518692,
#  502273,
#  501896,
#  474384,
#  518700,
#  493120,
#  453539,
#  279577,
#  595956,
#  451596,
#  608336,
#  520471,
#  592325,
#  451143,
#  611177,
#  541645,
#  594824,
#  448802,
#  544725,
#  114596,
#  458731,
#  434939,
#  572863,
#  641598,
#  490063,
#  431157,
#  594828,
#  518716,
#  571697,
#  502226,
#  407397,
#  425506,
#  460051,
#  114739,
#  543213,
#  114789,
#  543216,
#  502261,
#  460269,
#  136267,
#  340393,
#  572365,
#  502671,
#  430404,
#  543228,
#  460576,
#  408236,
#  471868,
#  136460,
#  471865,
#  452989,
#  570481,
#  461829,
#  114935,
#  503556,
#  592348,
#  571718,
#  460086,
#  605253,
#  543238,
#  488912,
#  594838,
#  518735,
#  434158,
#  592351,
#  502205,
#  407797,
#  425867,
#  460022,
#  544369,
#  606988,
#  425844,
#  545341,
#  115135,
#  663757,
#  408212,
#  543257,
#  648717,
#  115223,
#  665489,
#  136722,
#  115229,
#  641645,
#  666971,
#  493329,
#  429711,
#  446386,
#  150217,
#  461882,
#  608597,
#  448242,
#  576397,
#  400098,
#  150020,
#  430668,
#  407849,
#  430935,
#  571740,
#  285078,
#  434628,
#  641658,
#  452672,
#  571745,
#  435219,
#  593700,
#  462102,
#  664023,
#  457918,
#  421685,
#  429666,
#  429717,
#  547180,
#  430593,
#  407483,
#  543281,
#  430611,
#  518774,
#  656514,
#  425547,
#  451109,
#  571757,
#  452104,
#  592387,
#  588751,
#  595978,
#  502317,
#  476451,
#  136500,
#  115732,
#  543294,
#  628338,
#  435181,
#  435038,
#  514917,
#  571771,
#  491676,
#  115817,
#  593523,
#  150421,
#  606192,
#  599096,
#  467070,
#  468406,
#  546318,
#  594011,
#  543302,
#  518792,
#  543305,
#  518794,
#  543308,
#  431094,
#  425542,
#  400134,
#  669374,
#  543321,
#  451687,
#  592407,
#  407812,
#  571788,
#  534627,
#  656555,
#  543333,
#  429667,
#  407861,
#  218596,
#  333492,
#  471863,
#  460026,
#  116338,
#  455104,
#  116380,
#  578428,
#  542255,
#  408299,
#  276346,
#  446928,
#  448170,
#  493127,
#  285131,
#  430895,
#  457706,
#  433582,
#  429719,
#  408312,
#  457926,
#  608671,
#  643376,
#  452232,
#  444379,
#  445055,
#  457775,
#  116539,
#  650391,
#  434622,
#  492706,
#  453400,
#  430681,
#  471107,
#  435178,
#  430637,
#  276376,
#  407862,
#  453531,
#  430945,
#  116662,
#  116706,
#  434540,
#  592444,
#  571825,
#  543376,
#  571830,
#  459964,
#  592450,
#  457453,
#  451500,
#  501888,
#  628356,
#  137002,
#  493128,
#  400290,
#  608348,
#  430603,
#  571841,
#  461314,
#  643393,
#  116974,
#  435062,
#  452718,
#  150456,
#  453178,
#  596146,
#  433898,
#  477132,
#  595281,
#  547957,
#  643396,
#  664068,
#  435079,
#  543401,
#  623182,
#  595284,
#  543408,
#  117244,
#  425773,
#  117276,
#  435459,
#  450260,
#  518902,
#  456124,
#  571868,
#  430585,
#  493133,
#  600303,
#  407793,
#  501571,
#  445933,
#  408042,
#  516809,
#  534606,
#  571875,
#  150286,
#  407798,
#  458709,
#  453181,
#  425560,
#  451188,
#  150178,
#  502009,
#  657656,
#  543432,
#  543434,
#  502190,
#  150324,
#  424324,
#  493193,
#  117601,
#  518934,
#  506702,
#  452657,
#  430930,
#  452121,
#  150404,
#  453311,
#  452252,
#  596019,
#  434538,
#  446653,
#  641796,
#  502046,
#  346798,
#  543459,
#  425766,
#  446334,
#  150479,
#  430946,
#  670032,
#  547179,
#  117928,
#  518953,
#  664040,
#  117955,
#  136780,
#  476704,
#  448296,
#  518960,
#  407886,
#  608475,
#  150061,
#  656669,
#  543475,
#  458681,
#  553988,
#  592518,
#  628317,
#  430904,
#  543484,
#  430574,
#  571912,
#  455117,
#  641820,
#  622534,
#  545350,
#  455976,
#  150302,
#  571918,
#  453974,
#  429708,
#  527043,
#  606466,
#  516782,
#  547982,
#  621006,
#  431145,
#  593372,
#  502110,
#  500874,
#  492841,
#  400121,
#  518991,
#  458628,
#  425772,
#  425686,
#  430565,
#  150439,
#  571927,
#  408045,
#  622194,
#  452239,
#  460055,
#  457727,
#  608577,
#  435263,
#  543510,
#  453454,
#  457705,
#  150021,
#  150348,
#  431171,
#  502374,
#  641856,
#  434661,
#  641857,
#  643446,
#  640457,
#  523265,
#  642336,
#  640458,
#  474568,
#  593160,
#  519023,
#  346859,
#  519025,
#  137006,
#  425446,
#  489119,
#  132788,
#  451186,
#  543543,
#  571946,
#  501985,
#  506673,
#  134260,
#  150040,
#  425877,
#  660162,
#  609275,
#  428642,
#  524968,
#  471083,
#  664238,
#  445599,
#  489138,
#  206551,
#  434778,
#  592567,
#  543569,
#  519048,
#  460579,
#  408047,
#  621559,
#  489149,
#  434604,
#  450203,
#  461235,
#  600301,
#  519058,
#  656775,
#  571970,
#  622168,
#  502517,
#  461815,
#  430906,
#  571974,
#  608596,
#  571976,
#  294558,
#  435063,
#  571980,
#  553882,
#  537953,
#  425900,
#  519068,
#  647304,
#  502117,
#  455126,
#  621028,
#  477003,
#  543590,
#  408242,
#  607043,
#  434624,
#  425556,
#  605400,
#  543592,
#  445060,
#  502032,
#  519083,
#  119853,
#  456488,
#  600524,
#  656811,
#  502523,
#  641933,
#  596059,
#  660271,
#  324432,
#  400018,
#  621566,
#  592609,
#  120044,
#  449181,
#  434681,
#  542364,
#  120074,
#  591741,
#  400061,
#  407489,
#  572008,
#  542303,
#  457574,
#  434636,
#  594953,
#  605412,
#  517370,
#  592620,
#  476633,
#  467827,
#  519107,
#  543629,
#  279913,
#  452221,
#  449082,
#  425661,
#  572019,
#  134341,
#  456665,
#  592626,
#  456030,
#  460059,
#  430910,
#  150289,
#  455369,
#  452254,
#  460060,
#  444482,
#  425509,
#  503449,
#  606299,
#  542208,
#  541650,
#  543633,
#  547379,
#  521692,
#  519128,
#  607054,
#  451089,
#  463610,
#  502054,
#  572033,
#  408252,
#  621433,
#  429712,
#  334393,
#  150229,
#  489209,
#  607680,
#  444489,
#  640461,
#  517369,
#  572039,
#  608700,
#  461858,
#  325392,
#  570256,
#  593871,
#  135784,
#  572041,
#  120691,
#  457763,
#  445169,
#  445988,
#  502100,
#  445095,
#  595777,
#  624577,
#  405395,
#  346857,
#  435041,
#  425477,
#  596451,
#  435560,
#  279827,
#  430605,
#  493351,
#  133380,
#  434670,
#  623912,
#  608070,
#  120903,
#  467092,
#  285068,
#  458675,
#  592662,
#  592663,
#  489232,
#  502210,
#  430598,
#  608701,
#  460099,
#  543685,
#  592669,
#  650859,
#  121074,
#  434705,
#  519184,
#  614177,
#  408314,
#  622682,
#  668804,
#  448602,
#  608703,
#  489242,
#  453385,
#  572073,
#  595375,
#  663586,
#  425567,
#  407487,
#  425784,
#  608061,
#  592680,
#  519203,
#  543699,
#  406878,
#  440251,
#  543706,
#  621002,
#  519208,
#  453203,
#  645302,
#  121347,
#  121358,
#  425904,
#  500135,
#  446481,
#  434643,
#  595386,
#  500743,
#  121409,
#  276519,
#  464900,
#  461865,
#  519222,
#  602922,
#  489267,
#  642708,
#  592696,
#  501647,
#  425496,
#  424325,
#  475115,
#  400023,
#  607387,
#  573131,
#  448605,
#  434563,
#  547004,
#  519237,
#  608365,
#  592710,
#  489277,
#  453895,
#  547943,
#  573135,
#  400073,
#  457454,
#  502188,
#  447816,
#  434671,
#  408108,
#  459991,
#  596142,
#  516949,
#  456043,
#  570560,
#  467055,
#  543742,
#  ...]

# %%
# find David Ortiz's player id (mlbam_key)
# playerid_lookup('ortiz','david')

# get all available data
# data = statcast_batter('2008-04-01', '2017-07-15', player_id = 120074)

# get data for August 16th, 2014
# data = statcast_batter('2014-08-16', player_id = 120074)

# %%
def get_hitter_info(player_id):
    
    stats = statcast_batter('2008-05-01', '2020-10-27')
    return stats

# %%
# sc_data = statcast(start_dt='2008-05-01', end_dt= '2020-10-29')

# %%
sc_data = pd.read_csv('./statcast_data.csv')
# Out:
# /Users/johnnybex/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (44,88,89) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sc_data.head()
# Out:
#    index pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0      0         FF  2020-10-27           96.7           1.58           5.99
# 1      1         FF  2020-10-27           94.1           2.91           5.45
# 2      2         FF  2020-10-27           94.9           1.77           6.02
# 3      3         FF  2020-10-27           94.4           1.66           5.93
# 4      4         CU  2020-10-27           81.4           1.46           6.06
#
#    player_name    batter   pitcher     events      description  spin_dir  \
# 0  Julio Urias  642715.0  628711.0  strikeout    called_strike       NaN
# 1  Julio Urias  642715.0  628711.0        NaN    called_strike       NaN
# 2  Julio Urias  642715.0  628711.0        NaN  swinging_strike       NaN
# 3  Julio Urias  670712.0  628711.0  strikeout    called_strike       NaN
# 4  Julio Urias  670712.0  628711.0        NaN             ball       NaN
#
#    spin_rate_deprecated  break_angle_deprecated  break_length_deprecated  \
# 0                   NaN                     NaN                      NaN
# 1                   NaN                     NaN                      NaN
# 2                   NaN                     NaN                      NaN
# 3                   NaN                     NaN                      NaN
# 4                   NaN                     NaN                      NaN
#
#    zone                                     des game_type stand p_throws  \
# 0   4.0   Willy Adames called out on strikes.           W     R        L
# 1   1.0                                     NaN         W     R        L
# 2   2.0                                     NaN         W     R        L
# 3   4.0  Mike Brosseau called out on strikes.           W     R        L
# 4  13.0                                     NaN         W     R        L
#
#   home_team away_team type  hit_location bb_type  balls  strikes  game_year  \
# 0       LAD        TB    S           2.0     NaN    0.0      2.0     2020.0
# 1       LAD        TB    S           NaN     NaN    0.0      1.0     2020.0
# 2       LAD        TB    S           NaN     NaN    0.0      0.0     2020.0
# 3       LAD        TB    S           2.0     NaN    3.0      2.0     2020.0
# 4       LAD        TB    B           NaN     NaN    2.0      2.0     2020.0
#
#    pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b  on_1b  outs_when_up  inning  \
# 0   0.18   1.63    -0.53     2.29    NaN    NaN    NaN           2.0     9.0
# 1   0.75   1.30    -0.55     3.03    NaN    NaN    NaN           2.0     9.0
# 2   0.23   1.47    -0.04     3.32    NaN    NaN    NaN           2.0     9.0
# 3   0.27   1.50    -0.37     2.15    NaN    NaN    NaN           1.0     9.0
# 4  -1.67  -0.15    -0.14     0.96    NaN    NaN    NaN           1.0     9.0
#
#   inning_topbot  hc_x  hc_y  tfs_deprecated  tfs_zulu_deprecated  fielder_2  \
# 0           Top   NaN   NaN             NaN                  NaN   605131.0
# 1           Top   NaN   NaN             NaN                  NaN   605131.0
# 2           Top   NaN   NaN             NaN                  NaN   605131.0
# 3           Top   NaN   NaN             NaN                  NaN   605131.0
# 4           Top   NaN   NaN             NaN                  NaN   605131.0
#
#    umpire sv_id        vx0         vy0       vz0         ax         ay  \
# 0     NaN   NaN  -5.950264 -140.490456 -7.897391   3.772000  32.321911
# 1     NaN   NaN -10.560246 -136.599519 -3.429867  11.723598  29.183810
# 2     NaN   NaN  -5.199252 -138.098234 -4.637970   4.158758  30.838499
# 3     NaN   NaN  -5.843595 -137.294295 -7.414897   4.754147  30.016237
# 4     NaN   NaN  -0.383207 -118.447810 -4.454166 -15.553576  24.451936
#
#           az  sz_top  sz_bot  hit_distance_sc  launch_speed  launch_angle  \
# 0  -8.981441    3.50    1.69              NaN           NaN           NaN
# 1 -15.237217    3.50    1.69              NaN           NaN           NaN
# 2 -12.535677    3.50    1.69              NaN           NaN           NaN
# 3 -11.778755    3.34    1.53              NaN           NaN           NaN
# 4 -32.892744    3.34    1.53              NaN           NaN           NaN
#
#    effective_speed  release_spin_rate  release_extension   game_pk  pitcher.1  \
# 0             95.4             2615.0                5.7  635886.0   628711.0
# 1             93.4             2470.0                5.9  635886.0   628711.0
# 2             94.0             2397.0                5.7  635886.0   628711.0
# 3             93.7             2508.0                5.9  635886.0   628711.0
# 4             80.2             3031.0                5.7  635886.0   628711.0
#
#    fielder_2.1  fielder_3  fielder_4  fielder_5  fielder_6  fielder_7  \
# 0     605131.0   571970.0   571771.0   621458.0   608369.0   621035.0
# 1     605131.0   571970.0   571771.0   621458.0   608369.0   621035.0
# 2     605131.0   571970.0   571771.0   621458.0   608369.0   621035.0
# 3     605131.0   571970.0   571771.0   621458.0   608369.0   621035.0
# 4     605131.0   571970.0   571771.0   621458.0   608369.0   621035.0
#
#    fielder_8  fielder_9  release_pos_y  estimated_ba_using_speedangle  \
# 0   641355.0   605141.0          54.82                            NaN
# 1   641355.0   605141.0          54.59                            NaN
# 2   641355.0   605141.0          54.76                            NaN
# 3   641355.0   605141.0          54.60                            NaN
# 4   641355.0   605141.0          54.84                            NaN
#
#    estimated_woba_using_speedangle  woba_value  woba_denom  babip_value  \
# 0                              NaN         0.0         1.0          0.0
# 1                              NaN         NaN         NaN          NaN
# 2                              NaN         NaN         NaN          NaN
# 3                              NaN         0.0         1.0          0.0
# 4                              NaN         NaN         NaN          NaN
#
#    iso_value  launch_speed_angle  at_bat_number  pitch_number  \
# 0        0.0                 NaN           65.0           3.0
# 1        NaN                 NaN           65.0           2.0
# 2        NaN                 NaN           65.0           1.0
# 3        0.0                 NaN           64.0           6.0
# 4        NaN                 NaN           64.0           5.0
#
#         pitch_name  home_score  away_score  bat_score  fld_score  \
# 0  4-Seam Fastball         3.0         1.0        1.0        3.0
# 1  4-Seam Fastball         3.0         1.0        1.0        3.0
# 2  4-Seam Fastball         3.0         1.0        1.0        3.0
# 3  4-Seam Fastball         3.0         1.0        1.0        3.0
# 4        Curveball         3.0         1.0        1.0        3.0
#
#    post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 0              1.0              3.0             1.0             3.0
# 1              1.0              3.0             1.0             3.0
# 2              1.0              3.0             1.0             3.0
# 3              1.0              3.0             1.0             3.0
# 4              1.0              3.0             1.0             3.0
#
#   if_fielding_alignment of_fielding_alignment
# 0              Standard              Standard
# 1              Standard              Standard
# 2              Standard              Standard
# 3              Standard              Standard
# 4              Standard              Standard

# %%
sc_data.shape
# Out:
# (8842068, 90)

# %%
# initial columns 
init_cols = ['pitch_type', 'release_speed', 'batter', 'pitcher', 'events', 'description',
            'zone', 'p_throws', 'hit_location', 'balls', 'strikes', 'game_year',
            'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 'inning_topbot', 
             'fielder_2', 'ax', 'ay', 'az', 'hit_distance_sc', 'launch_speed',
            'launch_angle', 'effective_speed', 'release_spin_rate', 'release_extension',
            'game_pk', 'release_pos_y', 'estimated_ba_using_speedangle',
            'estimated_woba_using_speedangle', 'woba_value', 'woba_denom', 'babip_value',
            'iso_value', 'launch_speed_angle', 'at_bat_number', 'pitch_number',
            'pitch_name', 'bat_score', 'fld_score', 'if_fielding_alignment', 
             'of_fielding_alignment']

# %%
sc_data['batter'] = sc_data['batter'].astype(int)

# %%
vet_hitter_statcast = sc_data[sc_data['batter'].isin(hitter_ids)]

# %%
vet_hitter_statcast.head(-5)
# Out:
#          index pitch_type   game_date  release_speed  release_pos_x  \
# 0            0         FF  2020-10-27           96.7           1.58
# 1            1         FF  2020-10-27           94.1           2.91
# 2            2         FF  2020-10-27           94.9           1.77
# 9            9         FF  2020-10-27           95.2           1.72
# 10          10         CH  2020-10-27           87.2           1.90
# ...        ...        ...         ...            ...            ...
# 8842058  22467         FT  2008-05-01           87.3          -2.88
# 8842059  22470         FT  2008-05-01           88.6          -2.87
# 8842060  22485         FT  2008-05-01           87.7          -2.91
# 8842061  22494         FT  2008-05-01           88.0          -2.72
# 8842062  22501         FT  2008-05-01           87.9          -2.67
#
#          release_pos_z  player_name  batter   pitcher     events  \
# 0                 5.99  Julio Urias  642715  628711.0  strikeout
# 1                 5.45  Julio Urias  642715  628711.0        NaN
# 2                 6.02  Julio Urias  642715  628711.0        NaN
# 9                 6.09  Julio Urias  622534  628711.0  field_out
# 10                5.90  Julio Urias  622534  628711.0        NaN
# ...                ...          ...     ...       ...        ...
# 8842058           5.48  Ian Kennedy  122111  453178.0        NaN
# 8842059           5.60  Ian Kennedy  135784  453178.0  field_out
# 8842060           5.74  Ian Kennedy  135784  453178.0        NaN
# 8842061           5.50  Ian Kennedy  135784  453178.0        NaN
# 8842062           5.64  Ian Kennedy  135784  453178.0        NaN
#
#              description  spin_dir  spin_rate_deprecated  \
# 0          called_strike       NaN                   NaN
# 1          called_strike       NaN                   NaN
# 2        swinging_strike       NaN                   NaN
# 9          hit_into_play       NaN                   NaN
# 10                  foul       NaN                   NaN
# ...                  ...       ...                   ...
# 8842058    called_strike       NaN                   NaN
# 8842059    hit_into_play       NaN                   NaN
# 8842060             ball       NaN                   NaN
# 8842061             ball       NaN                   NaN
# 8842062             foul       NaN                   NaN
#
#          break_angle_deprecated  break_length_deprecated  zone  \
# 0                           NaN                      NaN   4.0
# 1                           NaN                      NaN   1.0
# 2                           NaN                      NaN   2.0
# 9                           NaN                      NaN   6.0
# 10                          NaN                      NaN   8.0
# ...                         ...                      ...   ...
# 8842058                     NaN                      NaN   5.0
# 8842059                     NaN                      NaN  49.0
# 8842060                     NaN                      NaN   NaN
# 8842061                     NaN                      NaN  58.0
# 8842062                     NaN                      NaN   2.0
#
#                                                        des game_type stand  \
# 0                    Willy Adames called out on strikes.           W     R
# 1                                                      NaN         W     R
# 2                                                      NaN         W     R
# 9        Manuel Margot flies out to right fielder Mooki...         W     R
# 10                                                     NaN         W     R
# ...                                                    ...       ...   ...
# 8842058                                                NaN         R     R
# 8842059  Placido Polanco flies out to center fielder Me...         R     R
# 8842060                                                NaN         R     R
# 8842061                                                NaN         R     R
# 8842062                                                NaN         R     R
#
#         p_throws home_team away_team type  hit_location   bb_type  balls  \
# 0              L       LAD        TB    S           2.0       NaN    0.0
# 1              L       LAD        TB    S           NaN       NaN    0.0
# 2              L       LAD        TB    S           NaN       NaN    0.0
# 9              L       LAD        TB    X           9.0  fly_ball    1.0
# 10             L       LAD        TB    S           NaN       NaN    1.0
# ...          ...       ...       ...  ...           ...       ...    ...
# 8842058        R       NYY       DET    S           NaN       NaN    0.0
# 8842059        R       NYY       DET    X           8.0  fly_ball    3.0
# 8842060        R       NYY       DET    B           NaN       NaN    2.0
# 8842061        R       NYY       DET    B           NaN       NaN    1.0
# 8842062        R       NYY       DET    S           NaN       NaN    1.0
#
#          strikes  game_year  pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b  \
# 0            2.0     2020.0   0.18   1.63    -0.53     2.29    NaN    NaN
# 1            1.0     2020.0   0.75   1.30    -0.55     3.03    NaN    NaN
# 2            0.0     2020.0   0.23   1.47    -0.04     3.32    NaN    NaN
# 9            2.0     2020.0   0.40   1.48     0.40     2.56    NaN    NaN
# 10           1.0     2020.0   1.29   0.30     0.16     1.78    NaN    NaN
# ...          ...        ...    ...    ...      ...      ...    ...    ...
# 8842058      0.0     2008.0  -1.46   1.76    -0.18     2.38    NaN    NaN
# 8842059      1.0     2008.0  -1.47   1.58     0.16     3.58    NaN    NaN
# 8842060      1.0     2008.0  -1.16   1.29    -0.40     4.30    NaN    NaN
# 8842061      1.0     2008.0  -1.25   1.46     1.26     2.10    NaN    NaN
# 8842062      0.0     2008.0  -1.34   1.70     0.25     2.71    NaN    NaN
#
#          on_1b  outs_when_up  inning inning_topbot    hc_x   hc_y  \
# 0          NaN           2.0     9.0           Top     NaN    NaN
# 1          NaN           2.0     9.0           Top     NaN    NaN
# 2          NaN           2.0     9.0           Top     NaN    NaN
# 9          NaN           0.0     9.0           Top  191.34  99.03
# 10         NaN           0.0     9.0           Top     NaN    NaN
# ...        ...           ...     ...           ...     ...    ...
# 8842058    NaN           2.0     1.0           Top     NaN    NaN
# 8842059    NaN           1.0     1.0           Top  107.43  51.20
# 8842060    NaN           1.0     1.0           Top     NaN    NaN
# 8842061    NaN           1.0     1.0           Top     NaN    NaN
# 8842062    NaN           1.0     1.0           Top     NaN    NaN
#
#          tfs_deprecated  tfs_zulu_deprecated  fielder_2  umpire  \
# 0                   NaN                  NaN   605131.0     NaN
# 1                   NaN                  NaN   605131.0     NaN
# 2                   NaN                  NaN   605131.0     NaN
# 9                   NaN                  NaN   605131.0     NaN
# 10                  NaN                  NaN   605131.0     NaN
# ...                 ...                  ...        ...     ...
# 8842058             NaN                  NaN        NaN     NaN
# 8842059             NaN                  NaN        NaN     NaN
# 8842060             NaN                  NaN        NaN     NaN
# 8842061             NaN                  NaN        NaN     NaN
# 8842062             NaN                  NaN        NaN     NaN
#
#                  sv_id        vx0         vy0       vz0         ax         ay  \
# 0                  NaN  -5.950264 -140.490456 -7.897391   3.772000  32.321911
# 1                  NaN -10.560246 -136.599519 -3.429867  11.723598  29.183810
# 2                  NaN  -5.199252 -138.098234 -4.637970   4.158758  30.838499
# 9                  NaN  -4.306764 -138.539023 -6.867868   6.166594  30.824839
# 10                 NaN  -6.787951 -126.842197 -4.319413  15.263710  25.705872
# ...                ...        ...         ...       ...        ...        ...
# 8842058  080501_191025   9.862000 -126.665000 -4.855000 -15.532000  26.385000
# 8842059  080501_190943  10.990000 -128.500000 -2.130000 -16.534000  20.764000
# 8842060  080501_190924   8.826000 -127.437000  0.170000 -12.467000  21.406000
# 8842061  080501_190908  12.728000 -127.384000 -5.188000 -13.450000  21.902000
# 8842062  080501_190843  10.185000 -127.499000 -4.415000 -14.284000  26.183000
#
#                 az  sz_top  sz_bot  hit_distance_sc  launch_speed  \
# 0        -8.981441    3.50    1.69              NaN           NaN
# 1       -15.237217    3.50    1.69              NaN           NaN
# 2       -12.535677    3.50    1.69              NaN           NaN
# 9       -11.731952    3.25    1.53            284.0          83.4
# 10      -28.270065    3.25    1.53              NaN           NaN
# ...            ...     ...     ...              ...           ...
# 8842058 -14.409000    3.23    1.45              NaN           NaN
# 8842059 -15.593000    2.90    1.30              NaN           NaN
# 8842060 -19.336000    2.90    1.30              NaN           NaN
# 8842061 -17.406000    2.90    1.30              NaN           NaN
# 8842062 -14.817000    2.90    1.30              NaN           NaN
#
#          launch_angle  effective_speed  release_spin_rate  release_extension  \
# 0                 NaN             95.4             2615.0                5.7
# 1                 NaN             93.4             2470.0                5.9
# 2                 NaN             94.0             2397.0                5.7
# 9                44.0             94.0             2450.0                5.6
# 10                NaN             86.6             2000.0                5.9
# ...               ...              ...                ...                ...
# 8842058           NaN              NaN                NaN                NaN
# 8842059           NaN              NaN                NaN                NaN
# 8842060           NaN              NaN                NaN                NaN
# 8842061           NaN              NaN                NaN                NaN
# 8842062           NaN              NaN                NaN                NaN
#
#           game_pk  pitcher.1  fielder_2.1  fielder_3  fielder_4  fielder_5  \
# 0        635886.0   628711.0     605131.0   571970.0   571771.0   621458.0
# 1        635886.0   628711.0     605131.0   571970.0   571771.0   621458.0
# 2        635886.0   628711.0     605131.0   571970.0   571771.0   621458.0
# 9        635886.0   628711.0     605131.0   571970.0   571771.0   621458.0
# 10       635886.0   628711.0     605131.0   571970.0   571771.0   621458.0
# ...           ...        ...          ...        ...        ...        ...
# 8842058  234180.0   453178.0          NaN        NaN        NaN        NaN
# 8842059  234180.0   453178.0          NaN        NaN        NaN        NaN
# 8842060  234180.0   453178.0          NaN        NaN        NaN        NaN
# 8842061  234180.0   453178.0          NaN        NaN        NaN        NaN
# 8842062  234180.0   453178.0          NaN        NaN        NaN        NaN
#
#          fielder_6  fielder_7  fielder_8  fielder_9  release_pos_y  \
# 0         608369.0   621035.0   641355.0   605141.0          54.82
# 1         608369.0   621035.0   641355.0   605141.0          54.59
# 2         608369.0   621035.0   641355.0   605141.0          54.76
# 9         608369.0   621035.0   641355.0   605141.0          54.92
# 10        608369.0   621035.0   641355.0   605141.0          54.61
# ...            ...        ...        ...        ...            ...
# 8842058        NaN        NaN        NaN        NaN          50.00
# 8842059        NaN        NaN        NaN        NaN          50.00
# 8842060        NaN        NaN        NaN        NaN          50.00
# 8842061        NaN        NaN        NaN        NaN          50.00
# 8842062        NaN        NaN        NaN        NaN          50.00
#
#          estimated_ba_using_speedangle  estimated_woba_using_speedangle  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 9                                0.029                             0.04
# 10                                 NaN                              NaN
# ...                                ...                              ...
# 8842058                            NaN                              NaN
# 8842059                            NaN                              NaN
# 8842060                            NaN                              NaN
# 8842061                            NaN                              NaN
# 8842062                            NaN                              NaN
#
#          woba_value  woba_denom  babip_value  iso_value  launch_speed_angle  \
# 0               0.0         1.0          0.0        0.0                 NaN
# 1               NaN         NaN          NaN        NaN                 NaN
# 2               NaN         NaN          NaN        NaN                 NaN
# 9               0.0         1.0          0.0        0.0                 3.0
# 10              NaN         NaN          NaN        NaN                 NaN
# ...             ...         ...          ...        ...                 ...
# 8842058         NaN         NaN          NaN        NaN                 NaN
# 8842059         0.0         NaN          0.0        0.0                 NaN
# 8842060         NaN         NaN          NaN        NaN                 NaN
# 8842061         NaN         NaN          NaN        NaN                 NaN
# 8842062         NaN         NaN          NaN        NaN                 NaN
#
#          at_bat_number  pitch_number       pitch_name  home_score  away_score  \
# 0                 65.0           3.0  4-Seam Fastball         3.0         1.0
# 1                 65.0           2.0  4-Seam Fastball         3.0         1.0
# 2                 65.0           1.0  4-Seam Fastball         3.0         1.0
# 9                 63.0           4.0  4-Seam Fastball         3.0         1.0
# 10                63.0           3.0         Changeup         3.0         1.0
# ...                ...           ...              ...         ...         ...
# 8842058            3.0           1.0  2-Seam Fastball         0.0         0.0
# 8842059            2.0           5.0  2-Seam Fastball         0.0         0.0
# 8842060            2.0           4.0  2-Seam Fastball         0.0         0.0
# 8842061            2.0           3.0  2-Seam Fastball         0.0         0.0
# 8842062            2.0           2.0  2-Seam Fastball         0.0         0.0
#
#          bat_score  fld_score  post_away_score  post_home_score  \
# 0              1.0        3.0              1.0              3.0
# 1              1.0        3.0              1.0              3.0
# 2              1.0        3.0              1.0              3.0
# 9              1.0        3.0              1.0              3.0
# 10             1.0        3.0              1.0              3.0
# ...            ...        ...              ...              ...
# 8842058        0.0        0.0              0.0              0.0
# 8842059        0.0        0.0              0.0              0.0
# 8842060        0.0        0.0              0.0              0.0
# 8842061        0.0        0.0              0.0              0.0
# 8842062        0.0        0.0              0.0              0.0
#
#          post_bat_score  post_fld_score if_fielding_alignment  \
# 0                   1.0             3.0              Standard
# 1                   1.0             3.0              Standard
# 2                   1.0             3.0              Standard
# 9                   1.0             3.0              Standard
# 10                  1.0             3.0              Standard
# ...                 ...             ...                   ...
# 8842058             0.0             0.0                   NaN
# 8842059             0.0             0.0                   NaN
# 8842060             0.0             0.0                   NaN
# 8842061             0.0             0.0                   NaN
# 8842062             0.0             0.0                   NaN
#
#         of_fielding_alignment
# 0                    Standard
# 1                    Standard
# 2                    Standard
# 9                    Standard
# 10                   Standard
# ...                       ...
# 8842058                   NaN
# 8842059                   NaN
# 8842060                   NaN
# 8842061                   NaN
# 8842062                   NaN
#
# [8460933 rows x 90 columns]

# %%
vet_hitter_statcast['game_date'].dtype
# Out:
# dtype('O')

# %%
vet_hitter_statcast.loc[:, 'game_date'] = pd.to_datetime(vet_hitter_statcast.loc[:, 'game_date'],
                                                        format= '%Y-%m-%d')

# %%
d = {}

for year, sc_year in vet_hitter_statcast.groupby(vet_hitter_statcast.game_date.dt.year):
    d['df_{}'.format(int(year))] = sc_year

# %%
df_2008 = d['df_2008']
df_2009 = d['df_2009']
df_2010 = d['df_2010']
df_2011 = d['df_2011']
df_2012 = d['df_2012']
df_2013 = d['df_2013']
df_2014 = d['df_2014']
df_2015 = d['df_2015']
df_2016 = d['df_2016']
df_2017 = d['df_2017']
df_2018 = d['df_2018']
df_2019 = d['df_2019']
df_2020 = d['df_2020']

# for i, key in enumerate(df_names):
#     df_names[i] = d[key]
#     print(df_2008)

# %%
df_2008['launch_speed'].isnull().sum()
# Out:
# 541456

# %%
df_2009['launch_speed'].isnull().sum()
# Out:
# 697771

# %%
df_2010['launch_speed'].isnull().sum()
# Out:
# 696228

# %%
df_2011['launch_speed'].isnull().sum()
# Out:
# 695413

# %%
df_2012['launch_speed'].isnull().sum()
# Out:
# 695321

# %%
df_2013['launch_speed'].isnull().sum() == len(df_2013)
# Out:
# True

# %%
df_2014['launch_speed'].isnull().sum() == len(df_2014)
# Out:
# True

# %%
df_2015['launch_speed'].isnull().sum() == len(df_2015)
# Out:
# False

# %%
df_2016['launch_speed'].isnull().sum() == len(df_2015)
# Out:
# False

# %%
df_2017['launch_speed'].isnull().sum()
# Out:
# 584799

# %%
df_2020['launch_speed'].isnull().sum()
# Out:
# 168068

# %%
# statcast_by_hitter = sc_data.groupby('batter')

# %%
statcast_by_hitter

# %%
statcast_by_h_init_cols

# %%
#sc_data.to_csv('statcast_data.csv', index=False)
